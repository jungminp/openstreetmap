# %% [markdown]
# # OpenStreetMap Data Case Study

# %% [markdown]
# ### 1. Map Area
#
# Boston, United States (https://mapzen.com/data/metro-extracts/metro/boston_massachusetts/)
#
# The OSM XMS file is 414 MB.
#
# I chose this area since I want to visit this area in a few months for a tour.

# %% [markdown]
# ### 2. Parsing the OSM file.
# As you can see from the following result, I counted each number of the tag.
#
# 'bounds': 1, 'member': 10763, 'nd': 2327487, 'node': 1932903, 'osm': 1, 'relation': 1241, 'tag': 892774, 'way': 308653

# %%
import os
import pprint
import xml.etree.ElementTree as ET


filename = "boston_massachusetts.osm" # osm filename
path = "C:\Users\Jungmin\Downloads" # directory contain the osm file
OSMFILE = os.path.join(path, filename)

# iterative parsing
def count_tags(filename):
    tags = {}
    for event, elem in ET.iterparse(filename):
        if elem.tag not in tags:
            tags[elem.tag] = 1
        else:
            tags[elem.tag] += 1
    return tags


tags = count_tags(OSMFILE)
pprint.pprint(tags)
# Out:
# {'bounds': 1,
#  'member': 10763,
#  'nd': 2327487,
#  'node': 1932903,
#  'osm': 1,
#  'relation': 1241,
#  'tag': 892774,
#  'way': 308653}

# %% [markdown]
# ### 3. Exploring the Data
# I checked the "k" value for each "tag" and saw if there were any potential problems.
#
# As you can see from the following result, problem characters are not really problems.

# %%
import re

lower = re.compile(r'^([a-z]|_)*$')
lower_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$')
problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')

def key_type(element, keys):
    if element.tag == "tag":
        key = element.attrib['k']
        if re.search(lower, key) != None:
            keys['lower'] += 1
        elif re.search(lower_colon, key) != None:
            keys['lower_colon'] += 1
        elif re.search(problemchars, key) != None:
            keys['problemchars'] += 1
            print(element.attrib['k'])
        else:
            keys['other'] += 1
    return keys

def process_map(filename):
    keys = {"lower": 0, "lower_colon": 0, "problemchars": 0, "other": 0}
    for _, element in ET.iterparse(filename):
        keys = key_type(element, keys)
    return keys

keys = process_map(OSMFILE)
pprint.pprint(keys)
# Out:
# study area
# service area
# Hours Of Operation
# Payment options
# campus building
# Jackson Square T Station
# {'lower': 784791, 'lower_colon': 67970, 'other': 40007, 'problemchars': 6}

# %% [markdown]
# ### 4. Sample Data and  Problems Encountered in the Map
# Unnecessary abbreviated street names such as 'Brentwood St'
#
# Incorrect postal codes (Boston area zip codes all begin with “02” however some portion of zip codes were outside this region. The length of zip codes should be 5.)

# %%
from collections import defaultdict

TAG_KEYS = ['addr:street', 'addr:postcode']
item_limit = 100
    
def examine_tags(osmfile, item_limit):
    print "Examining tag keys: {}".format(TAG_KEYS)
    osm_file = open(osmfile, "r")

    # initialize data with default set data structure
    data = defaultdict(set)

    # iterate through elements
    for _, elem in ET.iterparse(osm_file, events=("start",)):
        # check if the element is a node or way
        if elem.tag == "node" or elem.tag == "way":
            # iterate through children matching `tag`
            for tag in elem.iter("tag"):
                # skip if does not contain key-value pair
                if 'k' not in tag.attrib or 'v' not in tag.attrib:
                    continue
                key = tag.get('k')
                val = tag.get('v')
                # add to set if in tag keys of interest and is below the item limit
                if key in TAG_KEYS and len(data[key]) < item_limit:
                    data[key].add(val)
    return data

tag_data = dict(examine_tags(OSMFILE, item_limit))
pprint.pprint(tag_data)
# Out:
# Examining tag keys: ['addr:street', 'addr:postcode']
# {'addr:postcode': set(['01125',
#                        '01238',
#                        '01240',
#                        '01854',
#                        '01944',
#                        '02026',
#                        '02026-5036',
#                        '02108',
#                        '02109',
#                        '02110',
#                        '02110-1301',
#                        '02111',
#                        '02113',
#                        '02114',
#                        '02114-3203',
#                        '02115',
#                        '02116',
#                        '02118',
#                        '02119',
#                        '02120',
#                        '02121',
#                        '02122',
#                        '02124',
#                        '02125',
#                        '02126',
#                        '02127',
#                        '02128',
#                        '02129',
#                        '02130',
#                        '02131',
#                        '02131-3025',
#                        '02132',
#                        '02132-1239',
#                        '02132-3226',
#                        '02134',
#                        '02134-1305',
#                        '02134-1307',
#                        '02134-1313',
#                        '02134-1316',
#                        '02134-1321',
#                        '02134-1322',
#                        '02134-1409',
#                        '02134-1420',
#                        '02134-1433',
#                        '02135',
#                        '02136',
#                        '02136-2460',
#                        '02138',
#                        '02138-1901',
#                        '02138-2701',
#                        '02138-2706',
#                        '02138-2724',
#                        '02138-2742',
#                        '02138-2903',
#                        '02138-2933',
#                        '02138-3003',
#                        '02138-3824',
#                        '02139',
#                        '02140',
#                        '02140-1340',
#                        '02140-2215',
#                        '02141',
#                        '02142',
#                        '02143',
#                        '02144',
#                        '02145',
#                        '02149',
#                        '02150',
#                        '02151',
#                        '02152',
#                        '02155',
#                        '02159',
#                        '02169',
#                        '02170',
#                        '02184',
#                        '02186',
#                        '02190',
#                        '02199',
#                        '02205',
#                        '02210',
#                        '02215',
#                        '02228',
#                        '02284-6028',
#                        '02445',
#                        '02445-5841',
#                        '02445-7638',
#                        '02446',
#                        '02458',
#                        '02459',
#                        '02467',
#                        '02472',
#                        '02474',
#                        '02474-8735',
#                        '02476',
#                        '02478',
#                        'MA',
#                        'MA 02116',
#                        'MA 02118',
#                        'MA 02186',
#                        'Mass Ave']),
#  'addr:street': set(['1629 Cambridge St',
#                      '61 Union Square',
#                      'Agawam Road',
#                      'Albion Street',
#                      'Antwerp St',
#                      'Arlington Street',
#                      'Ashburton Place',
#                      'Ashley Street',
#                      'Athol St',
#                      'Avenue Louis Pasteur',
#                      'Bagnal St',
#                      'Beacon Street',
#                      'Belmont Street',
#                      'Berkeley Street',
#                      'Blossom Street',
#                      'Boston street',
#                      'Bow Street',
#                      'Brattle Street',
#                      'Brentwood St',
#                      'Brentwood Street',
#                      'Broadway',
#                      'Brookline Avenue',
#                      'Brookline Street',
#                      'Cambridge St',
#                      'Cambridge Street',
#                      'Charles River Avenue',
#                      'Clinton Street',
#                      'Colchester Street',
#                      'Columbus Avenue',
#                      'Commonwealth Avenue',
#                      'Congress St',
#                      'Crescent Street',
#                      'Dartmouth Street',
#                      'David G Mugar Way',
#                      'Dorchester Avenue',
#                      'Dudley Street',
#                      'East Berkeley Street',
#                      'East Newton Street',
#                      'Edge Hill Road',
#                      'Edwin H. Land Boulevard',
#                      'Elm Street',
#                      'Erie Street',
#                      'Everett St',
#                      'Everett Street',
#                      'Fawcett Street',
#                      'Fifth Street',
#                      'Franklin Street',
#                      'Garden Street',
#                      'George P Hassett Drive',
#                      'Gove Street',
#                      'Grant Avenue',
#                      'Green Street',
#                      'Hancock Street',
#                      'Harrison Avenue',
#                      'Harvard Avenue',
#                      'Harvard Street',
#                      'Highland Avenue',
#                      'Holland Street',
#                      'Holton St',
#                      'Huntington Avenue',
#                      'Hyde Park Avenue',
#                      'Landsdowne Street',
#                      'Linden Place',
#                      'Linnaean Street',
#                      'Litchfield St',
#                      'Magazine Street',
#                      'Main St.',
#                      'Main Street',
#                      'Massachusetts Avenue',
#                      'Massachussetts Avenue',
#                      'Matignon Road',
#                      'Medford St',
#                      'Medford Street',
#                      'Metropolitan Avenue',
#                      'Morton Street',
#                      'Mystic Valley Parkway',
#                      'Norris Street',
#                      'North Square',
#                      'Notre Dame Avenue',
#                      'Old Colony Avenue',
#                      'Pearl Street',
#                      'Puddingstone Lane',
#                      'Saint James Avenue',
#                      'Savin Hill Avenue',
#                      'Sidney Street',
#                      'Soldiers Field Rd',
#                      'Somerville Ave',
#                      'Somerville Ave.',
#                      'Sydney Street',
#                      'Trapelo Road',
#                      'Union Square',
#                      'Veterans Of Foreign Wars Parkway',
#                      'Walnut St,',
#                      'Washington Street',
#                      'Waverly Street',
#                      'West Roxbury Parkway',
#                      'Western Ave',
#                      'Western Avenue',
#                      'White Street',
#                      'Whitwell Street'])}

# %% [markdown]
# ### 5. Auditing Street Type
# I looked at the street names, and printed out all the street names that is with a unexpected street type.

# %%
street_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)

expected = ["Street", "Avenue", "Boulevard", "Drive", "Court", "Place", "Square", "Lane", "Road", 
            "Trail", "Parkway", "Commons"]

def audit_street_type(street_types, street_name):
    m = street_type_re.search(street_name)
    if m:
        street_type = m.group()
        if street_type not in expected:
            street_types[street_type].add(street_name)

def is_street_name(elem):
    return (elem.attrib['k'] == "addr:street")

def audit(osmfile):
    osm_file = open(osmfile, "r")
    street_types = defaultdict(set)
    for event, elem in ET.iterparse(osm_file, events=("start",)):

        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_street_name(tag):
                    audit_street_type(street_types, tag.attrib['v'])
    osm_file.close()
    return street_types

st_types = audit(OSMFILE)
pprint.pprint(dict(st_types))
# Out:
# {'1100': set(['First Street, Suite 1100']),
#  '1702': set(['Franklin Street, Suite 1702']),
#  '3': set(['Kendall Square - 3']),
#  '303': set(['First Street, Suite 303']),
#  '4': set(['Pier 4']),
#  '6': set(['South Station, near Track 6']),
#  '846028': set(['PO Box 846028']),
#  'Artery': set(['Southern Artery']),
#  'Ave': set(['738 Commonwealth Ave',
#              'Blue Hill Ave',
#              'Boston Ave',
#              'College Ave',
#              'Commonwealth Ave',
#              'Concord Ave',
#              'Everett Ave',
#              'Francesca Ave',
#              'Harrison Ave',
#              'Highland Ave',
#              'Josephine Ave',
#              'Lexington Ave',
#              'Massachusetts Ave',
#              'Morrison Ave',
#              'Mystic Ave',
#              'Sagamore Ave',
#              'Somerville Ave',
#              "St. Paul's Ave",
#              'Washington Ave',
#              'Western Ave',
#              'Willow Ave']),
#  'Ave.': set(['Brighton Ave.',
#               'Massachusetts Ave.',
#               'Somerville Ave.',
#               'Spaulding Ave.']),
#  'Broadway': set(['Broadway', 'West Broadway']),
#  'Brook': set(['Furnace Brook']),
#  'Cambrdige': set(['Cambrdige']),
#  'Center': set(['Cambridge Center']),
#  'Circle': set(['Achorn Circle', 'Edgewood Circle', 'Stein Circle']),
#  'Corner': set(['Webster Street, Coolidge Corner']),
#  'Ct': set(['Kelley Ct']),
#  'Elm': set(['Elm']),
#  'Federal': set(['Federal']),
#  'Fellsway': set(['Fellsway']),
#  'Fenway': set(['Fenway']),
#  'Floor': set(['Boylston Street, 5th Floor']),
#  'Greenway': set(['East Boston Greenway']),
#  'HIghway': set(['American Legion HIghway']),
#  'Hall': set(['Faneuil Hall']),
#  'Hampshire': set(['Hampshire']),
#  'Highway': set(['American Legion Highway',
#                  'Cummins Highway',
#                  "Monsignor O'Brien Highway",
#                  'Providence Highway',
#                  'Santilli Highway']),
#  'Holland': set(['Holland']),
#  'Hwy': set(["Monsignor O'Brien Hwy"]),
#  'Jamaicaway': set(['Jamaicaway']),
#  'LEVEL': set(['LOMASNEY WAY, ROOF LEVEL']),
#  'Lafayette': set(['Avenue De Lafayette']),
#  'Mall': set(['Cummington Mall']),
#  'Newbury': set(['Newbury']),
#  'Park': set(['Acorn Park',
#               'Agassiz Park',
#               'Austin Park',
#               'Batterymarch Park',
#               'Canal Park',
#               'Exeter Park',
#               'Giles Park',
#               'Greenough Park',
#               'Malden Street Park',
#               'Monument Park',
#               'Newsome Park']),
#  'Pasteur': set(['Avenue Louis Pasteur']),
#  'Pkwy': set(['Birmingham Pkwy']),
#  'Pl': set(['Longfellow Pl']),
#  'Plaza': set(['Two Center Plaza']),
#  'Rd': set(['Abby Rd',
#             'Aberdeen Rd',
#             'Bristol Rd',
#             'Goodnough Rd',
#             'Oakland Rd',
#             'Soldiers Field Rd',
#             'Squanto Rd']),
#  'Row': set(['Assembly Row', 'East India Row', 'Professors Row']),
#  'ST': set(['Newton ST']),
#  'South': set(['Charles Street South']),
#  'Sq.': set(['1 Kendall Sq.']),
#  'St': set(['1629 Cambridge St',
#             'Adams St',
#             'Antwerp St',
#             'Arsenal St',
#             'Athol St',
#             'Bagnal St',
#             'Brentwood St',
#             'Broad St',
#             'Cambridge St',
#             'Charles St',
#             'Congress St',
#             'Court St',
#             'Cummington St',
#             'Duval St',
#             'Elm St',
#             'Everett St',
#             'George St',
#             'Grove St',
#             'Hammond St',
#             'Hampshire St',
#             'Holton St',
#             'Kirkland St',
#             'Leighton St',
#             'Litchfield St',
#             'Lothrop St',
#             'Mackin St',
#             'Maverick St',
#             'Medford St',
#             'Merrill St',
#             'N Beacon St',
#             'Norfolk St',
#             'Portsmouth St',
#             'Richardson St',
#             'Sea St',
#             'South Waverly St',
#             'Stewart St',
#             'Ware St',
#             'Waverly St',
#             'Winter St']),
#  'St,': set(['Walnut St,']),
#  'St.': set(['Albion St.',
#              'Banks St.',
#              'Boylston St.',
#              'Brookline St.',
#              'Centre St.',
#              'Elm St.',
#              'Main St.',
#              'Marshall St.',
#              'Maverick St.',
#              'Pearl St.',
#              'Prospect St.',
#              "Saint Mary's St.",
#              'Stuart St.',
#              'Tremont St.']),
#  'Street.': set(['Hancock Street.']),
#  'Terrace': set(['Alberta Terrace',
#                  'Alveston Terrace',
#                  'Arborway Terrace',
#                  'Norfolk Terrace',
#                  'Westbourne Terrace']),
#  'Turnpike': set(['Boston Providence Turnpike']),
#  'Way': set(['Artisan Way',
#              'Ballard Way',
#              'Courthouse Way',
#              'David G Mugar Way',
#              'Davidson Way',
#              'Evans Way',
#              'Ross Way',
#              'Transportation Way',
#              'Yawkey Way']),
#  'Wharf': set(['Central Wharf', 'Long Wharf', 'Rowes Wharf']),
#  'Windsor': set(['Windsor']),
#  'Winsor': set(['Winsor']),
#  'floor': set(['First Street, 18th floor', 'Sidney Street, 2nd floor']),
#  'place': set(['argus place']),
#  'rd.': set(['Corey rd.']),
#  'st': set(['Main st']),
#  'street': set(['Boston street'])}

# %% [markdown]
# ### 6. Updating Street Name
# I updated street names.

# %%
# UPDATE THIS VARIABLE
mapping = { "Ave": "Avenue",
            "Ave.": "Avenue",
            "Ct": "Court",
            "Cambrdige": "Cambrdige Center",      
            "Elm": "Elm Street", 
            "Fenway": "Fenway Yawkey Way",           
            "Hwy": "Highway",
            "HIghway": "Highway",
            "LOMASNEY WAY, ROOF LEVEL": "Lomasney Way",
            "Pkwy": "Parkway",
            "Pl": "Place", 
            "Rd": "Road",
            "ST": "Street",
            "Sq.": "Square",           
            "St": "Street",           
            "St,": "Street",
            "St.": "Street",
            "Street.": "Street",
            "rd.": "Road",           
            "st": "Street",
            "street": "Street",
            "First Street, Suite 1100": "First Street",
            "Franklin Street, Suite 1702": "Franklin Street",           
            "Kendall Square - 3": "Kendall Square",
            "First Street, Suite 303": "First Street",
            "South Station, near Track 6": "South Station, Summer Street",
            "PO Box 846028": "846028 Surface Road",
            "Holland": "Holland Albany Street",
            "Windsor": "Windsor Stearns Hill Road",
            "Winsor": "Winsor Village Pilgrim Road",
            "Newbury": "Newbury Street",
            "First Street, 18th floor": "First Street",
            "Sidney Street, 2nd floor": "Sidney Street",           
            "Federal": "Federal Street",
            "Boylston Street, 5th Floor": "Boylston Street",
            "Hampshire": "Hampshire Street",
            "Webster Street, Coolidge Corner": "Webster Street",
            "Furnace Brook": "Furnace Brook Parkway",           
            "Faneuil Hall": "Faneuil Hall Market Street",
           }


def update_name(name, mapping):
    for key in mapping.keys():
        if name.find(key) != -1:
            name = name[:name.find(key)]+mapping[key]

    return name

# %% [markdown]
# ### 7. Auditing Zip Codes
# I looked at the Zip codes,and printed out all the Zip codes that are with an unexpected Zip code type

# %%
def audit_zipcodes(osmfile):
    # iter through all zip codes, collect all the zip codes that does not start with 02
    osm_file = open(osmfile, "r")
    zip_codes = {}
    for event, elem in ET.iterparse(osm_file, events=("start",)):
        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if (tag.attrib['k'] == "addr:postcode" and not tag.attrib['v'].startswith('02')) or (tag.attrib['k'] == "addr:postcode" and len(tag.attrib['v'])!=5):
                    if tag.attrib['v'] not in zip_codes:
                        zip_codes[tag.attrib['v']] = 1
                    else:
                        zip_codes[tag.attrib['v']] += 1
    return zip_codes

zipcodes = audit_zipcodes(OSMFILE)
for zipcode in zipcodes:
    print zipcode, zipcodes[zipcode]
# Out:
# 0239 1
# 01238 1
# 02132-3226 1
# 02138-2742 1
# 02134-1327 1
# 02131-4931 1
# 02445-5841 1
# 02134-1322 6
# 02134-1321 4
# 02134-1305 9
# 02138-1901 1
# 02134-1306 2
# 02138-2933 3
# 02140-2215 1
# 02474-8735 1
# 01240 1
# 02130-4803 1
# 02114-3203 1
# 02134-1316 3
# 02134-1318 2
# MA 02118 1
# MA 02116 3
# 01944 1
# 01125 1
# 02138-2736 2
# 02134-1433 11
# Mass Ave 1
# 02136-2460 1
# 02138-3824 1
# 02131-3025 2
# 02134-1317 4
# 02140-1340 1
# 02138-2901 4
# 02134-1312 1
# 02134-1313 4
# 02134-1311 4
# 02134-1442 5
# 02138-2801 4
# 02284-6028 1
# 01821 1
# 01854 1
# 02110-1301 1
# MA 02186 1
# 02138-2903 8
# 02134-1409 4
# MA 4
# 02138-3003 1
# 02138-2735 1
# 02132-1239 1
# 01250 1
# 02134-1420 9
# 02134-1307 29
# 02138-2701 8
# 02445-7638 1
# 02134-1319 5
# 02138-2762 1
# 02138-2763 1
# 02138-2706 3
# 02026-5036 1
# 02138-2724 1

# %% [markdown]
# ### 8. Updating Zip Codes
# The mistake zip codes not starting with "02" are only 10 in our dataset, so I changed those zip codes into '00000' to distinguish from other zip codes when I need to analyze dataset. Also, I changed the zip codes whose length were over 5.

# %%
# UPDATE THIS VARIABLE
mapping_zip = { "0239": "00000",
                "01238": "00000",
                "02132-3226": "02132",
                "02138-2742": "02138",
                "02134-1327": "02134",
                "02131-4931": "02131",
                "02445-5841": "02445",
                "02134-1322": "02134",
                "02134-1321": "02134",
                "02134-1305": "02134",
                "02138-1901": "02138",
                "02134-1306": "02134",
                "02138-2933": "02138",
                "02140-2215": "02140",
                "02474-8735": "02474",
                "01240": "00000",
                "02130-4803": "02130",
                "02114-3203": "02114",
                "02134-1316": "02134",
                "02134-1318": "02134",
                "MA 02118": "02118",
                "MA 02116": "02118",
                "01944": "00000",
                "01125": "00000",
                "02138-2736": "02138",
                "02134-1433": "02134",
                "Mass Ave": "00000",
                "02110-1301": "02110",
                "MA 02186": "02186",
                "02138-2903": "02138",
                "02134-1409": "02134",
                "02138-3003": "02138",
                "02138-2735": "02138",
                "02132-1239": "02132",
                "01250": "00000",
                "02134-1420": "02134",
                "02134-1307": "02134",
                "02138-2701": "02138",
                "02445-7638": "02445",
                "02134-1319": "02134",
                "02138-2762": "02138",
                "02138-2763": "02138",
                "02138-2706": "02138",
                "02026-5036": "02026",
                "02138-2724": "02138",
               }

def update_zipcode(zipcode, mapping_zip):
    for key in mapping_zip.keys():
        if zipcode.find(key) != -1:
            zipcode = zipcode[:zipcode.find(key)]+mapping_zip[key]
    return zipcode

# %% [markdown]
# ### 9. Inserting into database
# I tried to insert data into database and also updated what I want to correct such as street type and zipcodes.

# %%
import codecs
import json
from pymongo import MongoClient


CREATED = [ "version", "changeset", "timestamp", "user", "uid"]

def shape_element(element):
    node = {}
    node["created"]={}
    node["address"]={}
    node["pos"]=[]
    refs=[]

    if element.tag == "node" or element.tag == "way" :
        if "id" in element.attrib:
            node["id"]=element.attrib["id"]
        node["type"]=element.tag

        if "visible" in element.attrib.keys():
            node["visible"]=element.attrib["visible"]

        for elem in CREATED:
            if elem in element.attrib:
                node["created"][elem]=element.attrib[elem]
        if "lat" in element.attrib:
            node["pos"].append(float(element.attrib["lat"]))
        if "lon" in element.attrib:
            node["pos"].append(float(element.attrib["lon"]))

        for tag in element.iter("tag"):
            if not(problemchars.search(tag.attrib['k'])):
                if tag.attrib['k'] == "addr:housenumber":
                    node["address"]["housenumber"]=tag.attrib['v']
                if tag.attrib['k'] == "addr:postcode":
                    node["address"]["postcode"]=tag.attrib['v']
                    node["address"]["postcode"] = update_zipcode(node["address"]["postcode"], mapping_zip)                      
                if tag.attrib['k'] == "addr:street":
                    node["address"]["street"]=tag.attrib['v']
                    node["address"]["street"] = update_name(node["address"]["street"], mapping)                 
                if tag.attrib['k'].find("addr")==-1:
                    node[tag.attrib['k']]=tag.attrib['v']
        for nd in element.iter("nd"):
             refs.append(nd.attrib["ref"])
        if node["address"] =={}:
            node.pop("address", None)
        if refs != []:
           node["node_refs"]=refs
        return node
    else:
        return None


def process_map(file_in, pretty = False):
    file_out = "{0}.json".format(file_in)
    data = []
    with codecs.open(file_out, "w") as fo:
        for _, element in ET.iterparse(file_in):
            el = shape_element(element)
            if el:
                data.append(el)
                if pretty:
                    fo.write(json.dumps(el, indent=2)+"\n")
                else:
                    fo.write(json.dumps(el) + "\n")
    return data

# process the file
data = process_map(OSMFILE, True)

# %%
client = MongoClient()
db = client.Boston
collection = db.bostonMAP
collection.insert(data)
# Out:
# C:\Users\Jungmin\Anaconda2\lib\site-packages\ipykernel\__main__.py:4: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
# [ObjectId('57e2eff2a5b8f30e442549cc'),
#  ObjectId('57e2eff2a5b8f30e442549cd'),
#  ObjectId('57e2eff2a5b8f30e442549ce'),
#  ObjectId('57e2eff2a5b8f30e442549cf'),
#  ObjectId('57e2eff2a5b8f30e442549d0'),
#  ObjectId('57e2eff2a5b8f30e442549d1'),
#  ObjectId('57e2eff2a5b8f30e442549d2'),
#  ObjectId('57e2eff2a5b8f30e442549d3'),
#  ObjectId('57e2eff2a5b8f30e442549d4'),
#  ObjectId('57e2eff2a5b8f30e442549d5'),
#  ObjectId('57e2eff2a5b8f30e442549d6'),
#  ObjectId('57e2eff2a5b8f30e442549d7'),
#  ObjectId('57e2eff2a5b8f30e442549d8'),
#  ObjectId('57e2eff2a5b8f30e442549d9'),
#  ObjectId('57e2eff2a5b8f30e442549da'),
#  ObjectId('57e2eff2a5b8f30e442549db'),
#  ObjectId('57e2eff2a5b8f30e442549dc'),
#  ObjectId('57e2eff2a5b8f30e442549dd'),
#  ObjectId('57e2eff2a5b8f30e442549de'),
#  ObjectId('57e2eff2a5b8f30e442549df'),
#  ObjectId('57e2eff2a5b8f30e442549e0'),
#  ObjectId('57e2eff2a5b8f30e442549e1'),
#  ObjectId('57e2eff2a5b8f30e442549e2'),
#  ObjectId('57e2eff2a5b8f30e442549e3'),
#  ObjectId('57e2eff2a5b8f30e442549e4'),
#  ObjectId('57e2eff2a5b8f30e442549e5'),
#  ObjectId('57e2eff2a5b8f30e442549e6'),
#  ObjectId('57e2eff2a5b8f30e442549e7'),
#  ObjectId('57e2eff2a5b8f30e442549e8'),
#  ObjectId('57e2eff2a5b8f30e442549e9'),
#  ObjectId('57e2eff2a5b8f30e442549ea'),
#  ObjectId('57e2eff2a5b8f30e442549eb'),
#  ObjectId('57e2eff2a5b8f30e442549ec'),
#  ObjectId('57e2eff2a5b8f30e442549ed'),
#  ObjectId('57e2eff2a5b8f30e442549ee'),
#  ObjectId('57e2eff2a5b8f30e442549ef'),
#  ObjectId('57e2eff2a5b8f30e442549f0'),
#  ObjectId('57e2eff2a5b8f30e442549f1'),
#  ObjectId('57e2eff2a5b8f30e442549f2'),
#  ObjectId('57e2eff2a5b8f30e442549f3'),
#  ObjectId('57e2eff2a5b8f30e442549f4'),
#  ObjectId('57e2eff2a5b8f30e442549f5'),
#  ObjectId('57e2eff2a5b8f30e442549f6'),
#  ObjectId('57e2eff2a5b8f30e442549f7'),
#  ObjectId('57e2eff2a5b8f30e442549f8'),
#  ObjectId('57e2eff2a5b8f30e442549f9'),
#  ObjectId('57e2eff2a5b8f30e442549fa'),
#  ObjectId('57e2eff2a5b8f30e442549fb'),
#  ObjectId('57e2eff2a5b8f30e442549fc'),
#  ObjectId('57e2eff2a5b8f30e442549fd'),
#  ObjectId('57e2eff3a5b8f30e44254cfd'),
#  ObjectId('57e2eff3a5b8f30e44254cfe'),
#  ObjectId('57e2eff3a5b8f30e44254cff'),
#  ObjectId('57e2eff3a5b8f30e44254d00'),
#  ObjectId('57e2eff3a5b8f30e44254d01'),
#  ObjectId('57e2eff3a5b8f30e44254d02'),
#  ObjectId('57e2eff3a5b8f30e44254d03'),
#  ObjectId('57e2eff3a5b8f30e44254d04'),
#  ObjectId('57e2eff3a5b8f30e44254d05'),
#  ObjectId('57e2eff3a5b8f30e44254d06'),
#  ObjectId('57e2eff3a5b8f30e44254d07'),
#  ObjectId('57e2eff3a5b8f30e44254d08'),
#  ObjectId('57e2eff3a5b8f30e44254d09'),
#  ObjectId('57e2eff3a5b8f30e44254d0a'),
#  ObjectId('57e2eff3a5b8f30e44254d0b'),
#  ObjectId('57e2eff3a5b8f30e44254d0c'),
#  ObjectId('57e2eff3a5b8f30e44254d0d'),
#  ObjectId('57e2eff3a5b8f30e44254d0e'),
#  ObjectId('57e2eff3a5b8f30e44254d0f'),
#  ObjectId('57e2eff3a5b8f30e44254d10'),
#  ObjectId('57e2eff3a5b8f30e44254d11'),
#  ObjectId('57e2eff3a5b8f30e44254d12'),
#  ObjectId('57e2eff3a5b8f30e44254d13'),
#  ObjectId('57e2eff3a5b8f30e44254d14'),
#  ObjectId('57e2eff3a5b8f30e44254d15'),
#  ObjectId('57e2eff3a5b8f30e44254d16'),
#  ObjectId('57e2eff3a5b8f30e44254d17'),
#  ObjectId('57e2eff3a5b8f30e44254d18'),
#  ObjectId('57e2eff3a5b8f30e44254d19'),
#  ObjectId('57e2eff3a5b8f30e44254d1a'),
#  ObjectId('57e2eff3a5b8f30e44254d1b'),
#  ObjectId('57e2eff3a5b8f30e44254d1c'),
#  ObjectId('57e2eff3a5b8f30e44254d1d'),
#  ObjectId('57e2eff3a5b8f30e44254d1e'),
#  ObjectId('57e2eff3a5b8f30e44254d1f'),
#  ObjectId('57e2eff3a5b8f30e44254d20'),
#  ObjectId('57e2eff3a5b8f30e44254d21'),
#  ObjectId('57e2eff3a5b8f30e44254d22'),
#  ObjectId('57e2eff3a5b8f30e44254d23'),
#  ObjectId('57e2eff3a5b8f30e44254d24'),
#  ObjectId('57e2eff3a5b8f30e44254d25'),
#  ObjectId('57e2eff3a5b8f30e44254d26'),
#  ObjectId('57e2eff3a5b8f30e44254d27'),
#  ObjectId('57e2eff3a5b8f30e44254d28'),
#  ObjectId('57e2eff3a5b8f30e44254d29'),
#  ObjectId('57e2eff3a5b8f30e44254d2a'),
#  ObjectId('57e2eff3a5b8f30e44254d2b'),
#  ObjectId('57e2eff3a5b8f30e44254d2c'),
#  ObjectId('57e2eff3a5b8f30e44254d2d'),
#  ObjectId('57e2eff3a5b8f30e44254d2e'),
#  ObjectId('57e2eff3a5b8f30e44254d2f'),
#  ObjectId('57e2eff3a5b8f30e44254d30'),
#  ObjectId('57e2eff3a5b8f30e44254d31'),
#  ObjectId('57e2eff3a5b8f30e44254d32'),
#  ObjectId('57e2eff3a5b8f30e44254d33'),
#  ObjectId('57e2eff3a5b8f30e44254d34'),
#  ObjectId('57e2eff3a5b8f30e44254d35'),
#  ObjectId('57e2eff3a5b8f30e44254d36'),
#  ObjectId('57e2eff3a5b8f30e44254d37'),
#  ObjectId('57e2eff3a5b8f30e44254d38'),
#  ObjectId('57e2eff3a5b8f30e44254d39'),
#  ObjectId('57e2eff3a5b8f30e44254d3a'),
#  ObjectId('57e2eff3a5b8f30e44254d3b'),
#  ObjectId('57e2eff3a5b8f30e44254d3c'),
#  ObjectId('57e2eff3a5b8f30e44254d3d'),
#  ObjectId('57e2eff3a5b8f30e44254d3e'),
#  ObjectId('57e2eff3a5b8f30e44254d3f'),
#  ObjectId('57e2eff3a5b8f30e44254d40'),
#  ObjectId('57e2eff3a5b8f30e44254d41'),
#  ObjectId('57e2eff3a5b8f30e44254d42'),
#  ObjectId('57e2eff3a5b8f30e44254d43'),
#  ObjectId('57e2eff3a5b8f30e44254d44'),
#  ObjectId('57e2eff3a5b8f30e44254d45'),
#  ObjectId('57e2eff3a5b8f30e44254d46'),
#  ObjectId('57e2eff3a5b8f30e44254d47'),
#  ObjectId('57e2eff3a5b8f30e44254d48'),
#  ObjectId('57e2eff3a5b8f30e44254d49'),
#  ObjectId('57e2eff3a5b8f30e44254d4a'),
#  ObjectId('57e2eff3a5b8f30e44254d4b'),
#  ObjectId('57e2eff3a5b8f30e44254d4c'),
#  ObjectId('57e2eff3a5b8f30e44254d4d'),
#  ObjectId('57e2eff3a5b8f30e44254d4e'),
#  ObjectId('57e2eff3a5b8f30e44254d4f'),
#  ObjectId('57e2eff3a5b8f30e44254d50'),
#  ObjectId('57e2eff3a5b8f30e44254d51'),
#  ObjectId('57e2eff3a5b8f30e44254d52'),
#  ObjectId('57e2eff3a5b8f30e44254d53'),
#  ObjectId('57e2eff3a5b8f30e44254d54'),
#  ObjectId('57e2eff3a5b8f30e44254d55'),
#  ObjectId('57e2eff3a5b8f30e44254d56'),
#  ObjectId('57e2eff3a5b8f30e44254d57'),
#  ObjectId('57e2eff3a5b8f30e44254d58'),
#  ObjectId('57e2eff3a5b8f30e44254d59'),
#  ObjectId('57e2eff3a5b8f30e44254d5a'),
#  ObjectId('57e2eff3a5b8f30e44254d5b'),
#  ObjectId('57e2eff3a5b8f30e44254d5c'),
#  ObjectId('57e2eff3a5b8f30e44254d5d'),
#  ObjectId('57e2eff3a5b8f30e44254d5e'),
#  ObjectId('57e2eff3a5b8f30e44254d5f'),
#  ObjectId('57e2eff3a5b8f30e44254d60'),
#  ObjectId('57e2eff3a5b8f30e44254d61'),
#  ObjectId('57e2eff3a5b8f30e44254d62'),
#  ObjectId('57e2eff3a5b8f30e44254d63'),
#  ObjectId('57e2eff3a5b8f30e44254d64'),
#  ObjectId('57e2eff3a5b8f30e44254d65'),
#  ObjectId('57e2eff3a5b8f30e44254d66'),
#  ObjectId('57e2eff3a5b8f30e44254d67'),
#  ObjectId('57e2eff3a5b8f30e44254d68'),
#  ObjectId('57e2eff3a5b8f30e44254d69'),
#  ObjectId('57e2eff3a5b8f30e44254d6a'),
#  ObjectId('57e2eff3a5b8f30e44254d6b'),
#  ObjectId('57e2eff3a5b8f30e44254d6c'),
#  ObjectId('57e2eff3a5b8f30e44254d6d'),
#  ObjectId('57e2eff3a5b8f30e44254d6e'),
#  ObjectId('57e2eff3a5b8f30e44254d6f'),
#  ObjectId('57e2eff3a5b8f30e44254d70'),
#  ObjectId('57e2eff3a5b8f30e44254d71'),
#  ObjectId('57e2eff3a5b8f30e44254d72'),
#  ObjectId('57e2eff3a5b8f30e44254d73'),
#  ObjectId('57e2eff3a5b8f30e44254d74'),
#  ObjectId('57e2eff3a5b8f30e44254d75'),
#  ObjectId('57e2eff3a5b8f30e44254d76'),
#  ObjectId('57e2eff3a5b8f30e44254d77'),
#  ObjectId('57e2eff3a5b8f30e44254d78'),
#  ObjectId('57e2eff3a5b8f30e44254d79'),
#  ObjectId('57e2eff3a5b8f30e44254d7a'),
#  ObjectId('57e2eff3a5b8f30e44254d7b'),
#  ObjectId('57e2eff3a5b8f30e44254d7c'),
#  ObjectId('57e2eff3a5b8f30e44254d7d'),
#  ObjectId('57e2eff3a5b8f30e44254d7e'),
#  ObjectId('57e2eff3a5b8f30e44254d7f'),
#  ObjectId('57e2eff3a5b8f30e44254d80'),
#  ObjectId('57e2eff3a5b8f30e44254d81'),
#  ObjectId('57e2eff3a5b8f30e44254d82'),
#  ObjectId('57e2eff3a5b8f30e44254d83'),
#  ObjectId('57e2eff3a5b8f30e44254d84'),
#  ObjectId('57e2eff3a5b8f30e44254d85'),
#  ObjectId('57e2eff3a5b8f30e44254d86'),
#  ObjectId('57e2eff3a5b8f30e44254d87'),
#  ObjectId('57e2eff3a5b8f30e44254d88'),
#  ObjectId('57e2eff3a5b8f30e44254d89'),
#  ObjectId('57e2eff3a5b8f30e44254d8a'),
#  ObjectId('57e2eff3a5b8f30e44254d8b'),
#  ObjectId('57e2eff3a5b8f30e44254d8c'),
#  ObjectId('57e2eff3a5b8f30e44254d8d'),
#  ObjectId('57e2eff3a5b8f30e44254d8e'),
#  ObjectId('57e2eff3a5b8f30e44254d8f'),
#  ObjectId('57e2eff3a5b8f30e44254d90'),
#  ObjectId('57e2eff3a5b8f30e44254d91'),
#  ObjectId('57e2eff3a5b8f30e44254d92'),
#  ObjectId('57e2eff3a5b8f30e44254d93'),
#  ObjectId('57e2eff3a5b8f30e44254d94'),
#  ObjectId('57e2eff3a5b8f30e44254d95'),
#  ObjectId('57e2eff3a5b8f30e44254d96'),
#  ObjectId('57e2eff3a5b8f30e44254d97'),
#  ObjectId('57e2eff3a5b8f30e44254d98'),
#  ObjectId('57e2eff3a5b8f30e44254d99'),
#  ObjectId('57e2eff3a5b8f30e44254d9a'),
#  ObjectId('57e2eff3a5b8f30e44254d9b'),
#  ObjectId('57e2eff3a5b8f30e44254d9c'),
#  ObjectId('57e2eff3a5b8f30e44254d9d'),
#  ObjectId('57e2eff3a5b8f30e44254d9e'),
#  ObjectId('57e2eff3a5b8f30e44254d9f'),
#  ObjectId('57e2eff3a5b8f30e44254da0'),
#  ObjectId('57e2eff3a5b8f30e44254da1'),
#  ObjectId('57e2eff3a5b8f30e44254da2'),
#  ObjectId('57e2eff3a5b8f30e44254da3'),
#  ObjectId('57e2eff3a5b8f30e44254da4'),
#  ObjectId('57e2eff3a5b8f30e44254da5'),
#  ObjectId('57e2eff3a5b8f30e44254da6'),
#  ObjectId('57e2eff3a5b8f30e44254da7'),
#  ObjectId('57e2eff3a5b8f30e44254da8'),
#  ObjectId('57e2eff3a5b8f30e44254da9'),
#  ObjectId('57e2eff3a5b8f30e44254daa'),
#  ObjectId('57e2eff3a5b8f30e44254dab'),
#  ObjectId('57e2eff3a5b8f30e44254dac'),
#  ObjectId('57e2eff3a5b8f30e44254dad'),
#  ObjectId('57e2eff3a5b8f30e44254dae'),
#  ObjectId('57e2eff3a5b8f30e44254daf'),
#  ObjectId('57e2eff3a5b8f30e44254db0'),
#  ObjectId('57e2eff3a5b8f30e44254db1'),
#  ObjectId('57e2eff3a5b8f30e44254db2'),
#  ObjectId('57e2eff3a5b8f30e44254db3'),
#  ...]

# %%
collection
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), u'Boston'), u'bostonMAP')

# %% [markdown]
# ### 10. Overview statistics

# %%
# size of the original xml file
os.path.getsize(OSMFILE)/1024/1024
# Out:
# 414L

# %%
# size of the processed json file
os.path.getsize(os.path.join(path, "boston_massachusetts.osm.json"))/1024/1024
# Out:
# 640L

# %%
# Number of unique users
len(collection.group(["created.uid"], {}, {"count":0}, "function(o, p){p.count++}"))
# Out:
# 1187

# %%
# Number of nodes
collection.find({"type":"node"}).count()
# Out:
# 1932545

# %%
# Number of ways
collection.find({"type":"way"}).count()
# Out:
# 308568

# %% [markdown]
# ### 11. Additional exploration
# Top three users contribute most of dataset. It is supposed that they were forced to insert the initial dataset. Especially, 'crschmidt' contributed approaximately 54% of map.

# %%
# Top three users with most contributions

pipeline = [{"$group":{"_id": "$created.user",
                       "count": {"$sum": 1}}},
            {"$sort": {"count": -1}},
            {"$limit": 3}]
result = collection.aggregate(pipeline)

for x in xrange(3):
    get_record = result.next()
    print get_record
# Out:
# {u'count': 1204304, u'_id': u'crschmidt'}
# {u'count': 430624, u'_id': u'jremillard-massgis'}
# {u'count': 92178, u'_id': u'OceanVortex'}

# %%
# Proportion of the top three users' contributions
pipeline = [{"$group":{"_id": "$created.user",
                       "count": {"$sum": 1}}},
            {"$project": {"proportion": {"$divide" :["$count",collection.find().count()]}}},
            {"$sort": {"proportion": -1}},
            {"$limit": 3}]

result = collection.aggregate(pipeline)

for x in xrange(3):
    get_record = result.next()
    print get_record
# Out:
# {u'_id': u'crschmidt', u'proportion': 0.5372625087216202}
# {u'_id': u'jremillard-massgis', u'proportion': 0.19210940971360965}
# {u'_id': u'OceanVortex', u'proportion': 0.041122327526057795}

# %% [markdown]
# ### 12. Conclusion
#
# Because the open street map dataset is a human edited dataset, there were some errors as we expected. I tried to update data but actually the decision to handle with wrong data has to be changed depending on how to analyze it next. The best way is finding the true data and updating the wrong data into the true data, but it is not easy and sometimes it is waste of time.
# Also, I think if 'OpenStreetMap.org' offer the input screen to constrain what we can put the correct data such as 5 digit Zipcode, the dataset could be more precise.
